# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# reading two csv files(Lighting Condition 1)
data_intensity1 = pd.read_csv('blue_0_side_intensity.csv')
data_pressure1 = pd.read_csv('blue_0_lighting2_FSR.csv')

# %%
# reading two csv files(Lighting Condition 1)
data_intensity2 = pd.read_csv('blue_10_side_intensity.csv')
data_pressure2 = pd.read_csv('blue_10_lighting2_FSR.csv')

# %%
# reading two csv files(Lighting Condition 1)
data_intensity3 = pd.read_csv('blue_25_side_intensity.csv')
data_pressure3 = pd.read_csv('Blue_25_lighting2_FSR.csv')

# %%
# reading two csv files(Lighting Condition 1)
data_intensity4 = pd.read_csv('blue_35_side_intensity.csv')
data_pressure4 = pd.read_csv('Blue_35_lighting2_FSR.csv')

# %%
# reading two csv files(Lighting Condition 1)
data_intensity5 = pd.read_csv('blue_50_side_intensity.csv')
data_pressure5 = pd.read_csv('Blue_50_lighting2_FSR.csv')

# %%
# reading two csv files(Lighting Condition 1)
data_intensity6 = pd.read_csv('blue_65_side_intensity.csv')
data_pressure6 = pd.read_csv('Blue_65_lighting2_FSR.csv')

# %%
# adding header for brighness csv file
headerList_1 = ['Brightness', 'Reference_Time']
headerList2 = ['Input_Force','FSR_Force','Reference_Time','Pressure','FSR']

# %%
data_intensity1.to_csv("Intensity_Test1.csv", header=headerList_1, index=False)
data_pressure1.to_csv("Pressure_Test1.csv",header=headerList2, index=False)

data_intensity2.to_csv("Intensity_Test2.csv", header=headerList_1, index=False)
data_pressure2.to_csv("Pressure_Test2.csv",header=headerList2, index=False)

data_intensity3.to_csv("Intensity_Test3.csv", header=headerList_1, index=False)
data_pressure3.to_csv("Pressure_Test3.csv",header=headerList2, index=False)

data_intensity4.to_csv("Intensity_Test4.csv", header=headerList_1, index=False)
data_pressure4.to_csv("Pressure_Test4.csv",header=headerList2, index=False)

data_intensity5.to_csv("Intensity_Test5.csv", header=headerList_1, index=False)
data_pressure5.to_csv("Pressure_Test5.csv",header=headerList2, index=False)

data_intensity6.to_csv("Intensity_Test6.csv", header=headerList_1, index=False)
data_pressure6.to_csv("Pressure_Test6.csv",header=headerList2, index=False)

# %%
# reading two csv files(Lighting Condition 3)
Data_Intensity1 = pd.read_csv('Intensity_Test1.csv')
Data_Pressure1 = pd.read_csv('Pressure_Test1.csv')

# reading two csv files(Lighting Condition 3)
Data_Intensity2 = pd.read_csv('Intensity_Test2.csv')
Data_Pressure2 = pd.read_csv('Pressure_Test2.csv')

Data_Intensity3 = pd.read_csv('Intensity_Test3.csv')
Data_Pressure3 = pd.read_csv('Pressure_Test3.csv')

Data_Intensity4 = pd.read_csv('Intensity_Test4.csv')
Data_Pressure4 = pd.read_csv('Pressure_Test4.csv')

Data_Intensity5 = pd.read_csv('Intensity_Test5.csv')
Data_Pressure5 = pd.read_csv('Pressure_Test5.csv')

Data_Intensity6 = pd.read_csv('Intensity_Test6.csv')
Data_Pressure6 = pd.read_csv('Pressure_Test6.csv')

# %%
df_Pressure = Data_Pressure1.append([Data_Pressure2, Data_Pressure3, Data_Pressure4, Data_Pressure5, Data_Pressure6], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_26848\2203422209.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Pressure = Data_Pressure1.append([Data_Pressure2, Data_Pressure3, Data_Pressure4, Data_Pressure5, Data_Pressure6], ignore_index=True)

# %%
df_intensity = Data_Intensity1.append([Data_Intensity2, Data_Intensity3, Data_Intensity4, Data_Intensity5, Data_Intensity6], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_26848\2062274126.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_intensity = Data_Intensity1.append([Data_Intensity2, Data_Intensity3, Data_Intensity4, Data_Intensity5, Data_Intensity6], ignore_index=True)

# %%
df_intensity
# Out:
#     Brightness  Reference_Time
# 0   136.355355        135236.0
# 1   139.332332        135237.0
# 2   142.069069        135238.0
# 3   144.682683        135239.0
# 4   145.802803        135240.0
# 5   146.814815        135241.0
# 6   146.442442        135242.0
# 7   147.453453        135243.0
# 8   147.416416        135244.0
# 9   179.408408        135246.0
# 10  176.257257        135247.0
# 11  176.814815        135248.0
# 12  173.427427        135249.0
# 13  173.601602        135250.0
# 14  174.388388        135251.0
# 15  176.670671        135252.0
# 16  176.965966        135253.0
# 17  130.320320        135254.0
# 18  135.655656        135256.0
# 19  185.101101        135257.0
# 20  186.875876        135258.0
# 21  185.825826        135259.0
# 22  187.224224        135260.0
# 23  186.287287        135261.0
# 24  185.873874        135262.0
# 25  186.138138        135263.0
# 26  185.615616        135264.0
# 27  141.474474        135306.0
# 28  194.508509        135307.0
# ...

# %%
df_Pressure
# Out:
#     Input_Force  FSR_Force  Reference_Time  Pressure       FSR
# 0          0.00   0.059707          135236  0.082705   15.6878
# 1          0.00   0.051041          135237  0.070700   13.4200
# 2          0.00   0.054364          135238  0.075304   14.2900
# 3          0.00   0.051457          135239  0.071277   13.5290
# 4          0.00   0.059479          135240  0.082388   15.6280
# 5          0.00   0.056359          135241  0.078067   14.8120
# 6          0.00   0.056799          135242  0.078676   14.9270
# 7          0.00   0.052022          135243  0.072060   13.6770
# 8          0.00   0.055927          135244  0.077469   14.6990
# 9          0.49   0.396710          135246  0.549511  101.5098
# 10         0.49   0.404337          135247  0.560076  103.4004
# 11         0.49   0.401854          135248  0.556637  102.7852
# 12         0.49   0.397607          135249  0.550754  101.7324
# 13         0.49   0.404436          135250  0.560213  103.4248
# ...

# %%
Lighting_Condition3 = pd.merge(df_intensity, df_Pressure,on='Reference_Time',how='inner')

# %%
headerList3 = ['Brightness','Reference_Time','Input_Force','FSR_Force','Pressure','FSR']
Lighting_Condition3.to_csv("Lighting_Condition3.csv",header=headerList3, index=False)

# %%
#Run from here

# %%
Lighting_Condition3 = pd.read_csv('Lighting_Condition3.csv')

# %%
Lighting_Condition3
# Out:
#     Brightness  Reference_Time  Input_Force  FSR_Force  Pressure      FSR_mv  \
# 0   130.332332          135237         0.00   0.051135  0.070830   13.444519
# 1   130.682683          135239         0.00   0.051519  0.071363   13.545227
# 2   131.053453          135243         0.00   0.052096  0.072162   13.696289
# 3   131.690691          135238         0.00   0.054404  0.075359   14.300537
# 4   132.016416          135244         0.00   0.055944  0.077492   14.703369
# 5   132.314815          135241         0.00   0.060179  0.083358   15.811157
# 6   132.442442          135242         0.00   0.060564  0.083892   15.911865
# 7   133.028028          135240         0.00   0.060949  0.084425   16.012573
# 8   133.355355          135236         0.00   0.063454  0.087894   16.667175
# 9   133.065966          135253         0.49   0.371194  0.514167   95.169067
# 10  134.408408          135246         0.49   0.380503  0.527062   97.485352
# ...

# %%
x1 = Lighting_Condition3['FSR']
y1 = Lighting_Condition3['Brightness']

# %%
plt.plot(x1, y1,label='Lighting_Condition3')

plt.legend(loc='upper left')

plt.xlabel('FSR (Volts)')
plt.ylabel(' Brightness ')

plt.show()

# %%
# reading two csv files(Lighting Condition 1)
data_intensity1 = pd.read_csv('pink_0_side_intensity.csv')
data_pressure1 = pd.read_csv('pink_0_lighting2_FSR.csv')

data_intensity2 = pd.read_csv('pink_10_side_intensity.csv')
data_pressure2 = pd.read_csv('pink_10_lighting2_FSR.csv')

data_intensity3 = pd.read_csv('pink_25_side_intensity.csv')
data_pressure3 = pd.read_csv('pink_25_lighting2_FSR.csv')

data_intensity4 = pd.read_csv('pink_35_side_intensity.csv')
data_pressure4 = pd.read_csv('pink_35_lighting2_FSR.csv')

data_intensity5 = pd.read_csv('pink_50_side_intensity.csv')
data_pressure5 = pd.read_csv('pink_50_lighting2_FSR.csv')

data_intensity6 = pd.read_csv('pink_65_side_intensity.csv')
data_pressure6 = pd.read_csv('pink_65_lighting2_FSR.csv')

# %%
data_intensity1.to_csv("Intensity_violet_Test1.csv", header=headerList_1, index=False)
data_pressure1.to_csv("Pressure_violet_Test1.csv",header=headerList2, index=False)

data_intensity2.to_csv("Intensity_violet_Test2.csv", header=headerList_1, index=False)
data_pressure2.to_csv("Pressure_violet_Test2.csv",header=headerList2, index=False)

data_intensity3.to_csv("Intensity_violet_Test3.csv", header=headerList_1, index=False)
data_pressure3.to_csv("Pressure_violet_Test3.csv",header=headerList2, index=False)

data_intensity4.to_csv("Intensity_violet_Test4.csv", header=headerList_1, index=False)
data_pressure4.to_csv("Pressure_violet_Test4.csv",header=headerList2, index=False)

data_intensity5.to_csv("Intensity_violet_Test5.csv", header=headerList_1, index=False)
data_pressure5.to_csv("Pressure_violet_Test5.csv",header=headerList2, index=False)

data_intensity6.to_csv("Intensity_violet_Test6.csv", header=headerList_1, index=False)
data_pressure6.to_csv("Pressure_violet_Test6.csv",header=headerList2, index=False)

# %%
# reading two csv files(Lighting Condition 3)
Data_violet_Intensity1 = pd.read_csv('Intensity_violet_Test1.csv')
Data_violet_Pressure1 = pd.read_csv('Pressure_violet_Test1.csv')

# reading two csv files(Lighting Condition 3)
Data_violet_Intensity2 = pd.read_csv('Intensity_violet_Test2.csv')
Data_violet_Pressure2 = pd.read_csv('Pressure_violet_Test2.csv')

Data_violet_Intensity3 = pd.read_csv('Intensity_violet_Test3.csv')
Data_violet_Pressure3 = pd.read_csv('Pressure_violet_Test3.csv')

Data_violet_Intensity4 = pd.read_csv('Intensity_violet_Test4.csv')
Data_violet_Pressure4 = pd.read_csv('Pressure_violet_Test4.csv')

Data_violet_Intensity5 = pd.read_csv('Intensity_violet_Test5.csv')
Data_violet_Pressure5 = pd.read_csv('Pressure_violet_Test5.csv')

Data_violet_Intensity6 = pd.read_csv('Intensity_violet_Test6.csv')
Data_violet_Pressure6 = pd.read_csv('Pressure_violet_Test6.csv')

# %%
df_violet_Pressure = Data_violet_Pressure1.append([Data_violet_Pressure2, Data_violet_Pressure3, Data_violet_Pressure4, Data_violet_Pressure5, Data_violet_Pressure6], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_26848\2433309544.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_violet_Pressure = Data_violet_Pressure1.append([Data_violet_Pressure2, Data_violet_Pressure3, Data_violet_Pressure4, Data_violet_Pressure5, Data_violet_Pressure6], ignore_index=True)

# %%
df_violet_Intensity = Data_violet_Intensity1.append([Data_violet_Intensity2, Data_violet_Intensity3, Data_violet_Intensity4, Data_violet_Intensity5, Data_violet_Intensity6], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_26848\2758757607.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_violet_Intensity = Data_violet_Intensity1.append([Data_violet_Intensity2, Data_violet_Intensity3, Data_violet_Intensity4, Data_violet_Intensity5, Data_violet_Intensity6], ignore_index=True)

# %%
Lighting_pink_Condition3 = pd.merge(df_violet_Intensity, df_violet_Pressure,on='Reference_Time',how='inner')

# %%
headerList3 = ['Brightness','Reference_Time','Input_Force','FSR_Force','Pressure','FSR']
Lighting_pink_Condition3.to_csv("Lighting_pink_Condition3.csv",header=headerList3, index=False)

# %%
#for violet

# %%
Lighting_pink_Condition3 = pd.read_csv('Lighting_pink_Condition3.csv')

# %%
x2 = Lighting_pink_Condition3['FSR']
y2 = Lighting_pink_Condition3['Brightness']

# %%
plt.plot(x2, y2,label='Lighting_Condition3')

plt.legend(loc='upper left')

plt.xlabel('FSR (Volts)')
plt.ylabel(' Brightness')

plt.show()

# %%
x1 = Lighting_Condition3['FSR']
y1 = Lighting_Condition3['Brightness']


x2 = Lighting_pink_Condition3['FSR']
y2 = Lighting_pink_Condition3['Brightness']

plt.plot(x1, y1,label='Lighting_Condition1(Blue)')
plt.plot(x2, y2,label='Lighting_Condition1(Pink)')
plt.legend(loc='upper left')

plt.xlabel('FSR (Volts)')
plt.ylabel(' Brightness ')

plt.show()

# %%
# reading two csv files(Lighting Condition 1)
data_intensity1 = pd.read_csv('pink_0_side_intensity.csv')
data_pressure1 = pd.read_csv('pink_0_lighting1_FSR.csv')

data_intensity1 = pd.read_csv('pink_10_side_intensity.csv')
data_pressure1 = pd.read_csv('pink_10_lighting1_FSR.csv')

data_intensity1 = pd.read_csv('pink_25_side_intensity.csv')
data_pressure1 = pd.read_csv('pink_25_lighting1_FSR.csv')

data_intensity1 = pd.read_csv('pink_35_side_intensity.csv')
data_pressure1 = pd.read_csv('pink_35_lighting1_FSR.csv')

# %%
data_intensity1.to_csv("Intensity_pink_Test1.csv", header=headerList_1, index=False)
data_pressure1.to_csv("Pressure_pink_Test1.csv",header=headerList2, index=False)

data_intensity2.to_csv("Intensity_pink_Test2.csv", header=headerList_1, index=False)
data_pressure2.to_csv("Pressure_pink_Test2.csv",header=headerList2, index=False)

data_intensity3.to_csv("Intensity_pink_Test3.csv", header=headerList_1, index=False)
data_pressure3.to_csv("Pressure_pink_Test3.csv",header=headerList2, index=False)

data_intensity4.to_csv("Intensity_pink_Test4.csv", header=headerList_1, index=False)
data_pressure4.to_csv("Pressure_pink_Test4.csv",header=headerList2, index=False)

data_intensity5.to_csv("Intensity_pink_Test5.csv", header=headerList_1, index=False)
data_pressure5.to_csv("Pressure_pink_Test5.csv",header=headerList2, index=False)

# %%
# reading two csv files(Lighting Condition 3)
Data_pink_Intensity1 = pd.read_csv('Intensity_pink_Test1.csv')
Data_pink_Pressure1 = pd.read_csv('Pressure_pink_Test1.csv')

# reading two csv files(Lighting Condition 3)
Data_pink_Intensity2 = pd.read_csv('Intensity_pink_Test2.csv')
Data_pink_Pressure2 = pd.read_csv('Pressure_pink_Test2.csv')

Data_pink_Intensity3 = pd.read_csv('Intensity_pink_Test3.csv')
Data_pink_Pressure3 = pd.read_csv('Pressure_pink_Test3.csv')

Data_pink_Intensity4 = pd.read_csv('Intensity_pink_Test4.csv')
Data_pink_Pressure4 = pd.read_csv('Pressure_pink_Test4.csv')

Data_pink_Intensity5 = pd.read_csv('Intensity_pink_Test5.csv')
Data_pink_Pressure5 = pd.read_csv('Pressure_pink_Test5.csv')

# %%
df_pink_Pressure = Data_pink_Pressure1.append([Data_pink_Pressure2, Data_pink_Pressure3, Data_pink_Pressure4, Data_pink_Pressure5], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_27216\3272760261.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pink_Pressure = Data_pink_Pressure1.append([Data_pink_Pressure2, Data_pink_Pressure3, Data_pink_Pressure4, Data_pink_Pressure5], ignore_index=True)

# %%
df_pink_Intensity = Data_pink_Intensity1.append([Data_pink_Intensity2, Data_pink_Intensity3, Data_pink_Intensity4, Data_pink_Intensity5], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_27216\1475644394.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pink_Intensity = Data_pink_Intensity1.append([Data_pink_Intensity2, Data_pink_Intensity3, Data_pink_Intensity4, Data_pink_Intensity5], ignore_index=True)

# %%
Lighting_pink_Condition1 = pd.merge(df_pink_Intensity, df_pink_Pressure,on='Reference_Time',how='inner')

# %%
headerList3 = ['Brightness','Reference_Time','Pressure','FSR']
Lighting_pink_Condition1.to_csv("Lighting_pink_Condition1.csv",header=headerList3, index=False)

# %%
#for pink

# %%
Lighting_pink_Condition1 = pd.read_csv('Lighting_pink_Condition1.csv')

# %%
x3 = Lighting_violet_Condition1['Brightness']
y3 = Lighting_violet_Condition1['FSR']

# %%
plt.plot(x3, y3,label='Lighting_Condition1')

plt.legend(loc='upper left')

plt.xlabel('Brightness')
plt.ylabel('FSR (Volts)')

plt.show()

# %%
x1 = Lighting_Condition1['Brightness']
y1 = Lighting_Condition1['FSR']

x3 = Lighting_pink_Condition1['Brightness']
y3 = Lighting_pink_Condition1['FSR']

x2 = Lighting_violet_Condition1['Brightness']
y2 = Lighting_violet_Condition1['FSR']

plt.plot(x1, y1,label='Lighting_Condition1')
plt.plot(x2, y2,label='Lighting_Condition2')
plt.plot(x3, y3,label='Lighting_Condition3')
plt.legend(loc='upper left')

plt.xlabel('Brightness')
plt.ylabel('FSR (Volts)')

plt.show()
