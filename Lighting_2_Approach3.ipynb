# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# reading two csv files(Lighting Condition 2)
data2_intensity1 = pd.read_csv('blue_0_side_intensity.csv')
data2_pressure1 = pd.read_csv('blue_0_lighting2_FSR.csv')

# %%
# reading two csv files(Lighting Condition 2)
data2_intensity2 = pd.read_csv('blue_10_side_intensity.csv')
data2_pressure2 = pd.read_csv('blue_10_lighting2_FSR.csv')

# %%
# reading two csv files(Lighting Condition 2)
data2_intensity3 = pd.read_csv('blue_25_side_intensity.csv')
data2_pressure3 = pd.read_csv('blue_25_lighting2_FSR.csv')

# %%
# reading two csv files(Lighting Condition 2)
data2_intensity4 = pd.read_csv('blue_35_side_intensity.csv')
data2_pressure4 = pd.read_csv('blue_35_lighting2_FSR.csv')

# %%
# reading two csv files(Lighting Condition 2)
data2_intensity5 = pd.read_csv('blue_50_side_intensity.csv')
data2_pressure5 = pd.read_csv('blue_50_lighting2_FSR.csv')

# %%
# reading two csv files(Lighting Condition 2)
data2_intensity6 = pd.read_csv('blue_65_side_intensity.csv')
data2_pressure6 = pd.read_csv('blue_65_lighting2_FSR.csv')

# %%
# adding header for brighness csv file
headerList_1 = ['Brightness', 'Reference_Time']
headerList2 = ['Input_Force','FSR_Force','Reference_Time','Pressure','FSR']

# %%
data2_intensity1.to_csv("Intensity2_Test1.csv", header=headerList_1, index=False)
data2_pressure1.to_csv("Pressure2_Test1.csv",header=headerList2, index=False)

data2_intensity2.to_csv("Intensity2_Test2.csv", header=headerList_1, index=False)
data2_pressure2.to_csv("Pressure2_Test2.csv",header=headerList2, index=False)

data2_intensity3.to_csv("Intensity2_Test3.csv", header=headerList_1, index=False)
data2_pressure3.to_csv("Pressure2_Test3.csv",header=headerList2, index=False)

data2_intensity4.to_csv("Intensity2_Test4.csv", header=headerList_1, index=False)
data2_pressure4.to_csv("Pressure2_Test4.csv",header=headerList2, index=False)

data2_intensity5.to_csv("Intensity2_Test5.csv", header=headerList_1, index=False)
data2_pressure5.to_csv("Pressure2_Test5.csv",header=headerList2, index=False)

data2_intensity6.to_csv("Intensity2_Test6.csv", header=headerList_1, index=False)
data2_pressure6.to_csv("Pressure2_Test6.csv",header=headerList2, index=False)

# %%
# reading two csv files(Lighting Condition 3)
Data2_Intensity1 = pd.read_csv('Intensity2_Test1.csv')
Data2_Pressure1 = pd.read_csv('Pressure2_Test1.csv')

Data2_Intensity2 = pd.read_csv('Intensity2_Test2.csv')
Data2_Pressure2 = pd.read_csv('Pressure2_Test2.csv')

Data2_Intensity3 = pd.read_csv('Intensity2_Test3.csv')
Data2_Pressure3 = pd.read_csv('Pressure2_Test3.csv')

Data2_Intensity4 = pd.read_csv('Intensity2_Test4.csv')
Data2_Pressure4 = pd.read_csv('Pressure2_Test4.csv')

Data2_Intensity5 = pd.read_csv('Intensity2_Test5.csv')
Data2_Pressure5 = pd.read_csv('Pressure2_Test5.csv')

Data2_Intensity6 = pd.read_csv('Intensity2_Test6.csv')
Data2_Pressure6 = pd.read_csv('Pressure2_Test6.csv')

# %%
df2_Pressure = Data2_Pressure1.append([Data2_Pressure2, Data2_Pressure3, Data2_Pressure4, Data2_Pressure5, Data2_Pressure6], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_24084\3002608419.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2_Pressure = Data2_Pressure1.append([Data2_Pressure2, Data2_Pressure3, Data2_Pressure4, Data2_Pressure5, Data2_Pressure6], ignore_index=True)

# %%
df2_intensity = Data2_Intensity1.append([Data2_Intensity2, Data2_Intensity3, Data2_Intensity4, Data2_Intensity5, Data2_Intensity6], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_24084\19480335.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2_intensity = Data2_Intensity1.append([Data2_Intensity2, Data2_Intensity3, Data2_Intensity4, Data2_Intensity5, Data2_Intensity6], ignore_index=True)

# %%
df2_intensity
# Out:
#     Brightness  Reference_Time
# 0   136.355355        135236.0
# 1   139.332332        135237.0
# 2   142.069069        135238.0
# 3   144.682683        135239.0
# 4   145.802803        135240.0
# 5   146.814815        135241.0
# 6   146.442442        135242.0
# 7   147.453453        135243.0
# 8   147.416416        135244.0
# 9   179.408408        135246.0
# 10  176.257257        135247.0
# 11  176.814815        135248.0
# 12  173.427427        135249.0
# 13  173.601602        135250.0
# 14  174.388388        135251.0
# 15  176.670671        135252.0
# 16  176.965966        135253.0
# 17  130.320320        135254.0
# 18  135.655656        135256.0
# 19  185.101101        135257.0
# 20  186.875876        135258.0
# 21  185.825826        135259.0
# 22  187.224224        135260.0
# 23  186.287287        135261.0
# 24  185.873874        135262.0
# 25  186.138138        135263.0
# 26  185.615616        135264.0
# 27  141.474474        135306.0
# 28  194.508509        135307.0
# 29  193.976977        135308.0
# 30  194.310310        135309.0
# 31  194.809810        135310.0
# 32  194.667668        135311.0
# 33  194.363363        135312.0
# 34  194.227227        135313.0
# 35  194.267267        135314.0
# 36  133.901902        135316.0
# 37  131.955956        135317.0
# 38  131.615616        135318.0
# 39  131.649650        135319.0
# 40  134.238238        135320.0
# 41  131.907908        135321.0
# 42  133.932933        135322.0
# 43  131.509510        135323.0
# 44  143.831832        135324.0
# 45  138.525526        135326.0
# 46  138.731732        135327.0
# 47  138.948949        135328.0
# 48  138.958959        135329.0
# 49  138.809810        135330.0
# 50  138.781782        135331.0
# 51  139.319319        135332.0
# 52  137.922923        135333.0
# 53  139.514515        135334.0

# %%
df2_Pressure
# Out:
#     Input_Force  FSR_Force  Reference_Time  Pressure       FSR
# 0          0.00   0.060852          135236  0.084290   15.9870
# 1          0.00   0.054574          135237  0.075595   14.3450
# 2          0.00   0.058254          135238  0.080691   15.3076
# 3          0.00   0.052096          135239  0.072162   13.6963
# 4          0.00   0.056604          135240  0.078406   14.8760
# 5          0.00   0.058254          135241  0.080691   15.3076
# 6          0.00   0.056799          135242  0.078676   14.9270
# 7          0.00   0.052096          135243  0.072162   13.6963
# 8          0.00   0.060285          135244  0.083505   15.8388
# 9          0.49   0.400743          135246  0.555098  102.5098
# 10         0.49   0.400302          135247  0.554486  102.4004
# 11         0.49   0.397820          135248  0.551049  101.7852
# 12         0.49   0.405678          135249  0.561933  103.7324
# 13         0.49   0.400400          135250  0.554622  102.4248
# 14         0.49   0.405220          135251  0.561299  103.6191
# 15         0.49   0.395926          135252  0.548425  101.3154
# 16         0.49   0.403324          135253  0.558673  103.1494
# 17         0.49   0.402311          135254  0.557270  102.8984
# 18         0.98   0.817544          135256  1.132437  202.5820
# 19         0.98   0.808706          135257  1.120195  200.5250
# 20         0.98   0.811922          135258  1.124651  201.2740
# 21         0.98   0.809070          135259  1.120700  200.6100
# 22         0.98   0.817178          135260  1.131931  202.4970
# 23         0.98   0.811334          135261  1.123835  201.1370
# 24         0.98   0.817527          135262  1.132413  202.5780
# 25         0.98   0.808465          135263  1.119862  200.4690
# 26         0.98   0.817058          135264  1.131764  202.4690
# 27         1.96   1.592326          135306  2.205642  372.8750
# 28         1.96   1.593260          135307  2.206936  373.0690
# 29         1.96   1.590863          135308  2.203615  372.5710
# 30         1.96   1.583502          135309  2.193420  371.0410
# 31         1.96   1.590723          135310  2.203422  372.5420
# 32         1.96   1.592596          135311  2.206016  372.9310
# 33         1.96   1.584045          135312  2.194172  371.1540
# 34         1.96   1.586186          135313  2.197137  371.5990
# 35         1.96   1.593669          135314  2.207503  373.1540
# 36         2.94   2.341952          135316  3.244002  520.7160
# 37         2.94   2.336769          135317  3.236822  519.7450
# 38         2.94   2.342107          135318  3.244217  520.7450
# 39         2.94   2.336769          135319  3.236822  519.7450
# 40         2.94   2.348486          135320  3.253053  521.9390
# 41         2.94   2.340313          135321  3.241731  520.4090
# 42         2.94   2.346995          135322  3.250987  521.6600
# 43         2.94   2.337046          135323  3.237206  519.7970
# 44         2.94   2.335125          135324  3.234545  519.4370
# 45         3.92   3.150016          135326  4.363308  664.2200
# 46         3.92   3.144900          135327  4.356221  663.3580
# 47         3.92   3.151822          135328  4.365809  664.5240
# 48         3.92   3.147873          135329  4.360340  663.8590
# 49         3.92   3.139781          135330  4.349130  662.4950
# 50         3.92   3.151822          135331  4.365809  664.5240
# 51         3.92   3.137498          135332  4.345969  662.1100
# 52         3.92   3.146389          135333  4.358284  663.6090
# 53         3.92   3.153984          135334  4.368804  664.8880

# %%
Lighting_Condition3 = pd.merge(df2_intensity, df2_Pressure,on='Reference_Time',how='inner')

# %%
headerList3 = ['Brightness','Reference_Time','Input_Force','FSR_Force','Pressure','FSR']
Lighting_Condition3.to_csv("Lighting_Condition2.csv",header=headerList3, index=False)

# %%
#Run from here

# %%
Lighting_Condition2 = pd.read_csv('Lighting_Condition2.csv')

# %%
Lighting_Condition2
# Out:
#     Brightness  Reference_Time  Input_Force  FSR_Force  Pressure      FSR_mv  \
# 0   135.355355        135239.0         0.00   0.052096  0.072162   13.696289
# 1   135.723323        135243.0         0.00   0.052673  0.072961   13.847351
# 2   135.969069        135237.0         0.00   0.054597  0.075626   14.350891
# 3   137.182683        135240.0         0.00   0.056521  0.078291   14.854431
# 4   137.602803        135242.0         0.00   0.056714  0.078558   14.904785
# 5   137.814815        135238.0         0.00   0.058254  0.080691   15.307617
# 6   137.994244        135241.0         0.00   0.061142  0.084692   16.062927
# 7   138.053453        135244.0         0.00   0.062298  0.086293   16.365051
# 8   138.416416        135236.0         0.00   0.062876  0.087094   16.516113
# 9   141.257257        135252.0         0.49   0.371194  0.514167   95.169067
# 10  141.408408        135248.0         0.49   0.377668  0.523135   96.780396
# 11  142.114815        135247.0         0.49   0.380098  0.526501   97.384644
# 12  142.927427        135250.0         0.49   0.392260  0.543347  100.405884
# 13  143.016016        135246.0         0.49   0.400787  0.555159  102.520752
# 14  143.388388        135254.0         0.49   0.402210  0.557129  102.873230
# 15  144.170671        135253.0         0.49   0.403226  0.558536  103.125000
# 16  144.565966        135251.0         0.49   0.405259  0.561352  103.628540
# 17  144.820320        135249.0         0.49   0.409733  0.567550  104.736328
# 18  187.655656        135263.0         0.98   0.795680  1.102152  197.488403
# 19  191.101101        135257.0         0.98   0.800213  1.108431  198.545837
# 20  191.875876        135259.0         0.98   0.809072  1.120702  200.610352
# 21  192.025826        135261.0         0.98   0.811235  1.123698  201.113892
# 22  192.224224        135258.0         0.98   0.811884  1.124597  201.264954
# 23  192.872873        135264.0         0.98   0.817077  1.131791  202.473450
# 24  193.073874        135260.0         0.98   0.821408  1.137790  203.480530
# 25  193.238138        135262.0         0.98   0.826176  1.144394  204.588318
# 26  205.156156        135256.0         0.98   0.827043  1.145595  204.789734
# 27  205.474475        135309.0         1.96   1.559416  2.160057  366.023254
# 28  206.085085        135312.0         1.96   1.569558  2.174104  368.138123
# 29  206.976977        135313.0         1.96   1.576569  2.183816  369.598389
# 30  207.310310        135310.0         1.96   1.590612  2.203268  372.518921
# 31  207.809810        135308.0         1.96   1.590854  2.203604  372.569275
# 32  208.067668        135306.0         1.96   1.597159  2.212337  373.878479
# 33  208.363363        135311.0         1.96   1.607112  2.226124  375.942993
# 34  208.827227        135307.0         1.96   1.607841  2.227133  376.094055
# 35  209.267267        135314.0         1.96   1.617809  2.240941  378.158569
# 36  213.019019        135324.0         2.94   2.297955  3.183059  512.452698
# 37  213.955956        135317.0         2.94   2.310262  3.200105  514.768982
# 38  214.156156        135319.0         2.94   2.315351  3.207155  515.725708
# 39  214.649650        135323.0         2.94   2.326344  3.222383  517.790222
# 40  214.938238        135321.0         2.94   2.329565  3.226844  518.394470
# 41  215.079079        135316.0         2.94   2.341924  3.243963  520.710754
# 42  215.932933        135318.0         2.94   2.342193  3.244336  520.761108
# 43  221.509510        135322.0         2.94   2.352419  3.258500  522.674560
# 44  224.831832        135320.0         2.94   2.364546  3.275299  524.940491
# 45  243.525525        135332.0         3.92   3.125536  4.329400  660.090637
# 46  243.731732        135330.0         3.92   3.133886  4.340965  661.500549
# 47  244.948949        135327.0         3.92   3.144933  4.356268  663.363647
# 48  246.589590        135333.0         3.92   3.146427  4.358337  663.615418
# 49  246.809810        135329.0         3.92   3.147922  4.360407  663.867188
# 50  249.081782        135326.0         3.92   3.155996  4.371592  665.226746
# 51  249.319319        135328.0         3.92   3.163779  4.382373  666.535950
# 52  249.922923        135331.0         3.92   3.169772  4.390673  667.543030
# 53  250.514514        135334.0         3.92   3.171870  4.393580  667.895508
# 54         NaN             NaN          NaN        NaN       NaN    0.000000
#
#         FSR
# 0     272.0
# 1     275.0
# 2     285.0
# 3     295.0
# 4     296.0
# 5     304.0
# 6     319.0
# 7     325.0
# 8     328.0
# 9    1890.0
# 10   1922.0
# 11   1934.0
# 12   1994.0
# 13   2036.0
# 14   2043.0
# 15   2048.0
# 16   2058.0
# 17   2080.0
# 18   3922.0
# 19   3943.0
# 20   3984.0
# 21   3994.0
# 22   3997.0
# 23   4021.0
# 24   4041.0
# 25   4063.0
# 26   4067.0
# 27   7269.0
# 28   7311.0
# 29   7340.0
# 30   7398.0
# 31   7399.0
# 32   7425.0
# 33   7466.0
# 34   7469.0
# 35   7510.0
# 36  10177.0
# 37  10223.0
# 38  10242.0
# 39  10283.0
# 40  10295.0
# 41  10341.0
# 42  10342.0
# 43  10380.0
# 44  10425.0
# 45  13109.0
# 46  13137.0
# 47  13174.0
# 48  13179.0
# 49  13184.0
# 50  13211.0
# 51  13237.0
# 52  13257.0
# 53  13264.0
# 54      NaN

# %%
x1 = Lighting_Condition2['FSR']
y1 = Lighting_Condition2['Brightness']

# %%
plt.plot(x1, y1,label='Lighting_Condition2')

plt.legend(loc='upper left')

plt.xlabel('FSR (Volts)')
plt.ylabel('Brightness')

plt.show()

# %%
# reading two csv files(Lighting Condition 1)
data2_intensity1 = pd.read_csv('pink_0_side_intensity.csv')
data2_pressure1 = pd.read_csv('pink_0_lighting2_FSR.csv')

data2_intensity2 = pd.read_csv('pink_10_side_intensity.csv')
data2_pressure2 = pd.read_csv('pink_10_lighting2_FSR.csv')

data2_intensity3 = pd.read_csv('pink_25_side_intensity.csv')
data2_pressure3 = pd.read_csv('pink_25_lighting2_FSR.csv')

data2_intensity4 = pd.read_csv('pink_35_side_intensity.csv')
data2_pressure4 = pd.read_csv('pink_35_lighting2_FSR.csv')

data2_intensity5 = pd.read_csv('pink_50_side_intensity.csv')
data2_pressure5 = pd.read_csv('pink_50_lighting2_FSR.csv')

data2_intensity6 = pd.read_csv('pink_65_side_intensity.csv')
data2_pressure6 = pd.read_csv('pink_65_lighting2_FSR.csv')

# %%
data2_intensity1.to_csv("Intensity_violet_Test1.csv", header=headerList_1, index=False)
data2_pressure1.to_csv("Pressure_violet_Test1.csv",header=headerList2, index=False)

data2_intensity2.to_csv("Intensity_violet_Test2.csv", header=headerList_1, index=False)
data2_pressure2.to_csv("Pressure_violet_Test2.csv",header=headerList2, index=False)

data2_intensity3.to_csv("Intensity_violet_Test3.csv", header=headerList_1, index=False)
data2_pressure3.to_csv("Pressure_violet_Test3.csv",header=headerList2, index=False)

data2_intensity4.to_csv("Intensity_violet_Test4.csv", header=headerList_1, index=False)
data2_pressure4.to_csv("Pressure_violet_Test4.csv",header=headerList2, index=False)

data2_intensity5.to_csv("Intensity_violet_Test5.csv", header=headerList_1, index=False)
data2_pressure5.to_csv("Pressure_violet_Test5.csv",header=headerList2, index=False)

data2_intensity6.to_csv("Intensity_violet_Test6.csv", header=headerList_1, index=False)
data2_pressure6.to_csv("Pressure_violet_Test6.csv",header=headerList2, index=False)

# %%
# reading two csv files(Lighting Condition 3)
Data_violet_Intensity1 = pd.read_csv('Intensity_violet_Test1.csv')
Data_violet_Pressure1 = pd.read_csv('Pressure_violet_Test1.csv')

# reading two csv files(Lighting Condition 3)
Data_violet_Intensity2 = pd.read_csv('Intensity_violet_Test2.csv')
Data_violet_Pressure2 = pd.read_csv('Pressure_violet_Test2.csv')

Data_violet_Intensity3 = pd.read_csv('Intensity_violet_Test3.csv')
Data_violet_Pressure3 = pd.read_csv('Pressure_violet_Test3.csv')

Data_violet_Intensity4 = pd.read_csv('Intensity_violet_Test4.csv')
Data_violet_Pressure4 = pd.read_csv('Pressure_violet_Test4.csv')

Data_violet_Intensity5 = pd.read_csv('Intensity_violet_Test5.csv')
Data_violet_Pressure5 = pd.read_csv('Pressure_violet_Test5.csv')

Data_violet_Intensity6 = pd.read_csv('Intensity_violet_Test6.csv')
Data_violet_Pressure6 = pd.read_csv('Pressure_violet_Test6.csv')

# %%
df_violet_Pressure = Data_violet_Pressure1.append([Data_violet_Pressure2, Data_violet_Pressure3, Data_violet_Pressure4, Data_violet_Pressure5, Data_violet_Pressure6], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_24084\2433309544.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_violet_Pressure = Data_violet_Pressure1.append([Data_violet_Pressure2, Data_violet_Pressure3, Data_violet_Pressure4, Data_violet_Pressure5, Data_violet_Pressure6], ignore_index=True)

# %%
df_violet_Intensity = Data_violet_Intensity1.append([Data_violet_Intensity2, Data_violet_Intensity3, Data_violet_Intensity4, Data_violet_Intensity5, Data_violet_Intensity5], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_24084\4209174702.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_violet_Intensity = Data_violet_Intensity1.append([Data_violet_Intensity2, Data_violet_Intensity3, Data_violet_Intensity4, Data_violet_Intensity5, Data_violet_Intensity5], ignore_index=True)

# %%
Lighting_violet_Condition1 = pd.merge(df_violet_Intensity, df_violet_Pressure,on='Reference_Time',how='inner')

# %%
headerList3 = ['Brightness','Reference_Time','Input_Force','FSR_Force','Pressure','FSR']
Lighting_violet_Condition1.to_csv("Lighting_pink_Condition2.csv",header=headerList3, index=False)

# %%
#for violet

# %%
Lighting_violet_Condition1 = pd.read_csv('Lighting_pink_Condition2.csv')

# %%
x2 = Lighting_violet_Condition1['FSR']
y2 = Lighting_violet_Condition1['Brightness']

# %%
plt.plot(x2, y2,label='Lighting_Condition1')

plt.legend(loc='upper left')

plt.xlabel('FSR (Volts)')
plt.ylabel('Brightness')

plt.rcParams.update(plt.rcParamsDefault)

plt.show()

# %%
x1 = Lighting_Condition2['FSR']
y1 = Lighting_Condition2['Brightness']


x2 = Lighting_violet_Condition1['FSR']
y2 = Lighting_violet_Condition1['Brightness']

plt.plot(x1, y1,label='Lighting_Condition2(Blue)')
plt.plot(x2, y2,label='Lighting_Condition2(Pink)')
plt.legend(loc='upper left')

plt.xlabel('FSR (Volts)')
plt.ylabel(' Brightness ')

plt.show()

# %%
# reading two csv files(Lighting Condition 1)
data2_intensity1 = pd.read_csv('pink_0_side_intensity.csv')
data2_pressure1 = pd.read_csv('pink_0_lighting2_FSR.csv')

data2_intensity2 = pd.read_csv('pink_10_side_intensity.csv')
data2_pressure2 = pd.read_csv('pink_10_lighting2_FSR.csv')

data2_intensity3 = pd.read_csv('pink_25_side_intensity.csv')
data2_pressure3 = pd.read_csv('pink_25_lighting2_FSR.csv')

data2_intensity4 = pd.read_csv('pink_35_side_intensity.csv')
data2_pressure4 = pd.read_csv('pink_35_lighting2_FSR.csv')


data2_intensity5 = pd.read_csv('pink_50_side_intensity.csv')
data2_pressure5 = pd.read_csv('pink_50_lighting2_FSR.csv')

# %%
data2_intensity1.to_csv("Intensity_pink_Test1.csv", header=headerList_1, index=False)
data2_pressure1.to_csv("Pressure_pink_Test1.csv",header=headerList2, index=False)

data2_intensity2.to_csv("Intensity_pink_Test2.csv", header=headerList_1, index=False)
data2_pressure2.to_csv("Pressure_pink_Test2.csv",header=headerList2, index=False)

data2_intensity3.to_csv("Intensity_pink_Test3.csv", header=headerList_1, index=False)
data2_pressure3.to_csv("Pressure_pink_Test3.csv",header=headerList2, index=False)

data2_intensity4.to_csv("Intensity_pink_Test4.csv", header=headerList_1, index=False)
data2_pressure4.to_csv("Pressure_pink_Test4.csv",header=headerList2, index=False)

data2_intensity5.to_csv("Intensity_pink_Test5.csv", header=headerList_1, index=False)
data2_pressure5.to_csv("Pressure_pink_Test5.csv",header=headerList2, index=False)

# %%
# reading two csv files(Lighting Condition 3)
Data_pink_Intensity1 = pd.read_csv('Intensity_pink_Test1.csv')
Data_pink_Pressure1 = pd.read_csv('Pressure_pink_Test1.csv')

# reading two csv files(Lighting Condition 3)
Data_pink_Intensity2 = pd.read_csv('Intensity_pink_Test2.csv')
Data_pink_Pressure2 = pd.read_csv('Pressure_pink_Test2.csv')

Data_pink_Intensity3 = pd.read_csv('Intensity_pink_Test3.csv')
Data_pink_Pressure3 = pd.read_csv('Pressure_pink_Test3.csv')

Data_pink_Intensity4 = pd.read_csv('Intensity_pink_Test4.csv')
Data_pink_Pressure4 = pd.read_csv('Pressure_pink_Test4.csv')

Data_pink_Intensity5 = pd.read_csv('Intensity_pink_Test5.csv')
Data_pink_Pressure5 = pd.read_csv('Pressure_pink_Test5.csv')

# %%
df_pink_Pressure = Data_pink_Pressure1.append([Data_pink_Pressure2, Data_pink_Pressure3, Data_pink_Pressure4, Data_pink_Pressure5], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_27596\3272760261.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pink_Pressure = Data_pink_Pressure1.append([Data_pink_Pressure2, Data_pink_Pressure3, Data_pink_Pressure4, Data_pink_Pressure5], ignore_index=True)

# %%
df_pink_Intensity = Data_pink_Intensity1.append([Data_pink_Intensity2, Data_pink_Intensity3, Data_pink_Intensity4, Data_pink_Intensity5], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_27596\1475644394.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pink_Intensity = Data_pink_Intensity1.append([Data_pink_Intensity2, Data_pink_Intensity3, Data_pink_Intensity4, Data_pink_Intensity5], ignore_index=True)

# %%
df_pink_Intensity['Reference_Time'] = df_pink_Pressure['Reference_Time']

# %%
Lighting_pink_Condition2 = pd.merge(df_pink_Intensity, df_pink_Pressure,on='Reference_Time',how='inner')

# %%
Lighting_pink_Condition2
# Out:
#     Brightness  Reference_Time  Pressure    FSR
# 0   124.718954          180826  0.000021    336
# 1   124.390850          180827  0.000021    336
# 2   123.504575          180828  0.000021    320
# 3   119.962092          180829  0.000021    320
# 4   119.739869          180830  0.000021    352
# 5   119.300000          180831  0.000021    320
# 6   119.177778          180832  0.000021    320
# 7   119.476471          180833  0.000021    304
# 8   119.667320          180834  0.000021    336
# 9   119.667320          180834  0.000031   1280
# 10  110.720261          180834  0.000021    336
# 11  110.720261          180834  0.000031   1280
# 12  110.606536          180835  0.000029   1088
# 13  110.816340          180836  0.000031   1232
# 14  117.720915          180837  0.000033   1360
# 15  129.244444          180838  0.000030   1200
# 16  128.994118          180839  0.000031   1248
# 17  129.344444          180840  0.000031   1232
# 18  129.443137          180841  0.000026    848
# 19  125.281046          180842  0.000025    720
# 20  142.402614          180927  0.000057   2192
# 21  143.211111          180928  0.000070   2400
# 22  142.435294          180929  0.000062   2272
# 23  141.653595          180930  0.000066   2336
# 24  141.967320          180931  0.000059   2224
# 25  137.739216          180932  0.000059   2224
# 26  137.739216          180932  0.000000   5185
# 27  157.842484          180932  0.000059   2224
# 28  157.842484          180932  0.000000   5185
# 29  115.832680          180933  0.000069   2384
# 30  115.832680          180933  0.000000   5313
# 31  156.629412          180933  0.000069   2384
# 32  156.629412          180933  0.000000   5313
# 33  115.883660          180934  0.000049   2016
# 34  115.883660          180934  0.000000   5121
# 35  154.953595          180934  0.000049   2016
# 36  154.953595          180934  0.000000   5121
# 37  115.496732          180935  0.000043   1840
# 38  115.496732          180935  0.000000   4977
# 39  139.649020          180935  0.000043   1840
# 40  139.649020          180935  0.000000   4977
# 41  113.879085          180936  0.000000   4833
# 42  113.640523          180937  0.000000   4817
# 43  114.488235          180938  0.000000   4609
# 44  114.404575          180939  0.000000   4257
# 45  115.529412          180940  0.000000   4145
# 46  181.547059          180961  0.000000  10642
# 47  180.734641          180962  0.000000  10306
# 48  183.492157          180963  0.000000  10690
# 49  180.269935          180964  0.000000  10498
# 50  181.312418          180965  0.000000  10514
# 51  163.862745          180966  0.000000  10210
# 52  114.084314          180967  0.000000  10178
# 53  114.328758          180968  0.000000  10258
# 54  113.723529          180969  0.000000  10274

# %%
headerList3 = ['Brightness','Reference_Time','Pressure','FSR']
Lighting_pink_Condition2.to_csv("Lighting_pink_Condition2.csv",header=headerList3, index=False)

# %%
df_pink_Intensity
# Out:
#     Brightness  Reference_Time
# 0   124.718954         52506.0
# 1   124.390850         52507.0
# 2   123.504575         52508.0
# 3   119.962092         52509.0
# 4   119.739869         52510.0
# 5   119.300000         52511.0
# 6   119.177778         52512.0
# 7   119.476471         52513.0
# 8   119.667320         52514.0
# 9   110.720261         52514.0
# 10  110.606536         52515.0
# 11  110.816340         52516.0
# 12  117.720915         52517.0
# 13  129.244444         52518.0
# 14  128.994118         52519.0
# 15  129.344444         52520.0
# 16  129.443137         52521.0
# 17  125.281046         52522.0
# 18  142.402614         52607.0
# 19  143.211111         52608.0
# 20  142.435294         52609.0
# 21  141.653595         52610.0
# 22  141.967320         52611.0
# 23  137.739216         52612.0
# 24  115.832680         52613.0
# 25  115.883660         52614.0
# 26  115.496732         52615.0
# 27  157.842484         52612.0
# 28  156.629412         52613.0
# 29  154.953595         52614.0
# 30  139.649020         52615.0
# 31  113.879085         52616.0
# 32  113.640523         52617.0
# 33  114.488235         52618.0
# 34  114.404575         52619.0
# 35  115.529412         52620.0
# 36  181.547059         52641.0
# 37  180.734641         52642.0
# 38  183.492157         52643.0
# 39  180.269935         52644.0
# 40  181.312418         52645.0
# 41  163.862745         52646.0
# 42  114.084314         52647.0
# 43  114.328758         52648.0
# 44  113.723529         52649.0

# %%
#for pink

# %%
Lighting_pink_Condition2 = pd.read_csv('Lighting_pink_Condition2.csv')

# %%
x3 = Lighting_pink_Condition2['Brightness']
y3 = Lighting_pink_Condition2['FSR']

# %%
plt.plot(x3, y3,label='Lighting_Condition1')

plt.legend(loc='upper left')

plt.xlabel('Brightness')
plt.ylabel('FSR (Volts)')

plt.show()

# %%
x1 = Lighting_Condition2['Brightness']
y1 = Lighting_Condition2['FSR']

x3 = Lighting_pink_Condition2['Brightness']
y3 = Lighting_pink_Condition2['FSR']

x2 = Lighting_violet_Condition1['Brightness']
y2 = Lighting_violet_Condition1['FSR']

plt.plot(x1, y1,label='Background_Blue')
plt.plot(x2, y2,label='Background_Violet')
plt.plot(x3, y3,label='background_Pink')
plt.legend(loc='upper left')

plt.xlabel('Brightness')
plt.ylabel('FSR (Volts)')

plt.show()
