# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
Lighting_Condition1_blue = pd.read_csv('Lighting_Condition1.csv')

Lighting_Condition2_blue = pd.read_csv('Lighting_Condition2.csv')


Lighting_Condition3_blue = pd.read_csv('Lighting_Condition3.csv')

# %%
Light1_blue_x = Lighting_Condition1_blue['FSR']
Light1_blue_y = Lighting_Condition1_blue['Brightness']


Light2_blue_x = Lighting_Condition2_blue['FSR']
Light2_blue_y = Lighting_Condition2_blue['Brightness']


Light3_blue_x = Lighting_Condition3_blue['FSR']
Light3_blue_y = Lighting_Condition3_blue['Brightness']

# %%
'''
plt.plot(Light1_blue_x, Light1_blue_y,label='Lighting Condition 1(blue)')
plt.plot(Light2_blue_x, Light2_blue_y,label='Lighting Condition 2 (blue)')
plt.plot(Light3_blue_x, Light3_blue_y,label='Lighting Condition 2 (blue)')
plt.legend(loc='upper left')

plt.xlabel('Brightness')
plt.ylabel('FSR (Volts)')

plt.show()'''
# Out:
# "\nplt.plot(Light1_blue_x, Light1_blue_y,label='Lighting Condition 1(blue)')\nplt.plot(Light2_blue_x, Light2_blue_y,label='Lighting Condition 2 (blue)')\nplt.plot(Light3_blue_x, Light3_blue_y,label='Lighting Condition 2 (blue)')\nplt.legend(loc='upper left')\n\nplt.xlabel('Brightness')\nplt.ylabel('FSR (Volts)')\n\nplt.show()"

# %%
Light1_blue_x1 = Lighting_Condition1_blue['Input_Force']
Light1_blue_y1 = Lighting_Condition1_blue['FSR_Force']

Light2_blue_x1 = Lighting_Condition2_blue['Input_Force']
Light2_blue_y1 = Lighting_Condition2_blue['FSR_Force']

Light3_blue_x1 = Lighting_Condition3_blue['Input_Force']
Light3_blue_y1 = Lighting_Condition3_blue['FSR_Force']
plt.plot(Light1_blue_x1, Light1_blue_y1,label='Lighting Condition 1(blue)')
plt.plot(Light2_blue_x1, Light2_blue_y1,label='Lighting Condition 2 (blue)')
plt.plot(Light3_blue_x1, Light3_blue_y1,label='Lighting Condition 3 (blue)')
plt.legend(loc='upper left')

plt.xlabel('Force Input (N)')
plt.ylabel('Force Output (N)')

plt.show()

# %%
Light1_blue_x = Lighting_Condition1_blue['Pressure']
Light1_blue_y = Lighting_Condition1_blue['Brightness']

Light2_blue_x = Lighting_Condition2_blue['Pressure']
Light2_blue_y = Lighting_Condition2_blue['Brightness']

Light3_blue_x = Lighting_Condition3_blue['Pressure']
Light3_blue_y = Lighting_Condition3_blue['Brightness']
plt.plot(Light1_blue_x, Light1_blue_y,label='Lighting Condition 1(blue)')
plt.plot(Light2_blue_x, Light2_blue_y,label='Lighting Condition 2 (blue)')
plt.plot(Light3_blue_x, Light3_blue_y,label='Lighting Condition 3 (blue)')
plt.legend(loc='upper left')

plt.xlabel('Pressure (N/mm^2)')
plt.ylabel('Brightness')

plt.show()

# %%
Lighting_Condition1_pink = pd.read_csv('Lighting_pink_Condition1.csv')

Lighting_Condition2_pink = pd.read_csv('Lighting_pink_Condition2.csv')


Lighting_Condition3_pink = pd.read_csv('Lighting_pink_Condition3.csv')

# %%
Light1_pink_x = Lighting_Condition1_pink['Brightness']
Light1_pink_y = Lighting_Condition1_pink['FSR']

Light2_pink_x = Lighting_Condition2_pink['Brightness']
Light2_pink_y = Lighting_Condition2_pink['FSR']

Light3_pink_x = Lighting_Condition3_pink['Brightness']
Light3_pink_y = Lighting_Condition3_pink['FSR']

# %%
'''
plt.plot(Light1_violet_x, Light1_violet_y,label='Lighting Condition 1(Violet)')
plt.plot(Light2_violet_x, Light2_violet_y,label='Lighting Condition 2 (Violet)')
plt.plot(Light3_violet_x, Light3_violet_y,label='Lighting Condition 3 (Violet)')
plt.legend(loc='upper left')

plt.xlabel('Brightness')
plt.ylabel('FSR (Volts)')

plt.show()'''
# Out:
# "\nplt.plot(Light1_violet_x, Light1_violet_y,label='Lighting Condition 1(Violet)')\nplt.plot(Light2_violet_x, Light2_violet_y,label='Lighting Condition 2 (Violet)')\nplt.plot(Light3_violet_x, Light3_violet_y,label='Lighting Condition 3 (Violet)')\nplt.legend(loc='upper left')\n\nplt.xlabel('Brightness')\nplt.ylabel('FSR (Volts)')\n\nplt.show()"

# %%
Light1_pink_x = Lighting_Condition1_pink['Pressure']
Light1_pink_y = Lighting_Condition1_pink['Brightness']

Light2_pink_x = Lighting_Condition2_pink['Pressure']
Light2_pink_y = Lighting_Condition2_pink['Brightness']

Light3_pink_x = Lighting_Condition3_pink['Pressure']
Light3_pink_y = Lighting_Condition3_pink['Brightness']

# %%
plt.plot(Light1_pink_x, Light1_pink_y,label='Lighting Condition 1(Violet)')
plt.plot(Light2_pink_x, Light2_pink_y,label='Lighting Condition 2 (Violet)')
plt.plot(Light3_pink_x, Light3_pink_y,label='Lighting Condition 3 (Violet)')
plt.legend(loc='upper left')

plt.xlabel('Pressure (N/mm^2)')
plt.ylabel(' Brightness ')

plt.show()

# %%
Light1_pink_x1 = Lighting_Condition1_pink['Input_Force']
Light1_pink_y1 = Lighting_Condition1_pink['FSR_Force']

Light2_pink_x1 = Lighting_Condition2_pink['Input_Force']
Light2_pink_y1 = Lighting_Condition2_pink['FSR_Force']

Light3_pink_x1 = Lighting_Condition3_pink['Input_Force']
Light3_pink_y1 = Lighting_Condition3_pink['FSR_Force']
plt.plot(Light1_pink_x1, Light1_pink_y1,label='Lighting Condition 1(pink)')
plt.plot(Light2_pink_x1, Light2_pink_y1,label='Lighting Condition 2 (pink)')
plt.plot(Light3_pink_x1, Light3_pink_y1,label='Lighting Condition 2 (pink)')
plt.legend(loc='upper left')

plt.xlabel('Force Input (N)')
plt.ylabel('Force Output (N)')

plt.show()

# %%
Lighting_Condition1_pink = pd.read_csv('Lighting_pink_Condition1.csv')

Lighting_Condition2_pink = pd.read_csv('Lighting_pink_Condition2.csv')


Lighting_Condition3_pink = pd.read_csv('Lighting_pink_Condition3.csv')

# %%
Light1_pink_x = Lighting_Condition1_pink['Brightness']
Light1_pink_y = Lighting_Condition1_pink['FSR']

Light2_pink_x = Lighting_Condition2_pink['Brightness']
Light2_pink_y = Lighting_Condition2_pink['FSR']

Light3_pink_x = Lighting_Condition3_pink['Brightness']
Light3_pink_y = Lighting_Condition3_pink['FSR']

# %%
'''
plt.plot(Light1_pink_x, Light1_pink_y,label='Lighting Condition 1(Pink)')
plt.plot(Light2_pink_x, Light2_pink_y,label='Lighting Condition 2 (Pink)')
plt.plot(Light3_pink_x, Light3_pink_y,label='Lighting Condition 3 (Pink)')
plt.legend(loc='upper left')

plt.xlabel('Brightness')
plt.ylabel('FSR (Volts)')

plt.show()'''
# Out:
# "\nplt.plot(Light1_pink_x, Light1_pink_y,label='Lighting Condition 1(Pink)')\nplt.plot(Light2_pink_x, Light2_pink_y,label='Lighting Condition 2 (Pink)')\nplt.plot(Light3_pink_x, Light3_pink_y,label='Lighting Condition 3 (Pink)')\nplt.legend(loc='upper left')\n\nplt.xlabel('Brightness')\nplt.ylabel('FSR (Volts)')\n\nplt.show()"

# %%
Light1_pink_x = Lighting_Condition1_pink['Pressure']
Light1_pink_y = Lighting_Condition1_pink['Brightness']

Light2_pink_x = Lighting_Condition2_pink['Pressure']
Light2_pink_y = Lighting_Condition2_pink['Brightness']

Light3_pink_x = Lighting_Condition3_pink['Pressure']
Light3_pink_y = Lighting_Condition3_pink['Brightness']

# %%
plt.plot(Light1_pink_x, Light1_pink_y,label='Lighting Condition 1(Pink)')
plt.plot(Light2_pink_x, Light2_pink_y,label='Lighting Condition 2 (Pink)')
plt.plot(Light3_pink_x, Light3_pink_y,label='Lighting Condition 3 (Pink)')
plt.legend(loc='upper left')

plt.xlabel('Pressure (N/mm^2)')
plt.ylabel('Brightness')

plt.show()

# %%
# reading two csv files(Lighting Condition 3)
data2_intensity2 = pd.read_csv('blue_10_side_intensity.csv')
data2_pressure2 = pd.read_csv('Blue_10_lighting3_FSR.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [86], in <module>
#       1 # reading two csv files(Lighting Condition 3)
# ----> 2 data2_intensity2 = pd.read_csv('blue_10_side_intensity.csv')
#       3 data2_pressure2 = pd.read_csv('Blue_10_lighting3_FSR.csv')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# reading two csv files(Lighting Condition 3)
data2_intensity3 = pd.read_csv('blue_25_side_intensity.csv')
data2_pressure3 = pd.read_csv('Blue_25_lighting3_FSR.csv')

# %%
# reading two csv files(Lighting Condition 3)
data2_intensity4 = pd.read_csv('blue_35_side_intensity.csv')
data2_pressure4 = pd.read_csv('Blue_35_lighting3_FSR.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [87], in <module>
#       1 # reading two csv files(Lighting Condition 3)
# ----> 2 data2_intensity4 = pd.read_csv('blue_35_side_intensity.csv')
#       3 data2_pressure4 = pd.read_csv('Blue_35_lighting3_FSR.csv')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# reading two csv files(Lighting Condition 3)
data2_intensity1 = pd.read_csv('blue_0_side_intensity.csv')
data2_pressure1 = pd.read_csv('Blue_0_lighting3_FSR.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [88], in <module>
#       1 # reading two csv files(Lighting Condition 3)
# ----> 2 data2_intensity1 = pd.read_csv('blue_0_side_intensity.csv')
#       3 data2_pressure1 = pd.read_csv('Blue_0_lighting3_FSR.csv')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# reading two csv files(Lighting Condition 3)
data2_intensity5 = pd.read_csv('blue_50_side_intensity.csv')
data2_pressure5 = pd.read_csv('Blue_50_lighting3_FSR.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [89], in <module>
#       1 # reading two csv files(Lighting Condition 3)
# ----> 2 data2_intensity5 = pd.read_csv('blue_50_side_intensity.csv')
#       3 data2_pressure5 = pd.read_csv('Blue_50_lighting3_FSR.csv')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# adding header for brighness csv file
headerList_1 = ['Brightness', 'Reference_Time']
headerList2 = ['Reference_Time','Pressure','FSR']

# %%
data2_intensity1.to_csv("Intensity2_Test1.csv", header=headerList_1, index=False)
data2_pressure1.to_csv("Pressure2_Test1.csv",header=headerList2, index=False)

data2_intensity2.to_csv("Intensity2_Test2.csv", header=headerList_1, index=False)
data2_pressure2.to_csv("Pressure2_Test2.csv",header=headerList2, index=False)

data2_intensity3.to_csv("Intensity2_Test3.csv", header=headerList_1, index=False)
data2_pressure3.to_csv("Pressure2_Test3.csv",header=headerList2, index=False)

data2_intensity4.to_csv("Intensity2_Test4.csv", header=headerList_1, index=False)
data2_pressure4.to_csv("Pressure2_Test4.csv",header=headerList2, index=False)

data2_intensity5.to_csv("Intensity2_Test5.csv", header=headerList_1, index=False)
data2_pressure5.to_csv("Pressure2_Test5.csv",header=headerList2, index=False)

# %%
# reading two csv files(Lighting Condition 3)
Data2_Intensity1 = pd.read_csv('Intensity2_Test1.csv')
Data2_Pressure1 = pd.read_csv('Pressure2_Test1.csv')

# reading two csv files(Lighting Condition 3)
Data2_Intensity2 = pd.read_csv('Intensity2_Test2.csv')
Data2_Pressure2 = pd.read_csv('Pressure2_Test2.csv')

Data2_Intensity3 = pd.read_csv('Intensity2_Test3.csv')
Data2_Pressure3 = pd.read_csv('Pressure2_Test3.csv')

Data2_Intensity4 = pd.read_csv('Intensity2_Test4.csv')
Data2_Pressure4 = pd.read_csv('Pressure2_Test4.csv')

Data2_Intensity5 = pd.read_csv('Intensity2_Test5.csv')
Data2_Pressure5 = pd.read_csv('Pressure2_Test5.csv')

# %%
df2_Pressure = Data2_Pressure1.append([Data2_Pressure2, Data2_Pressure3, Data2_Pressure4, Data2_Pressure5], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_17356\2343631227.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2_Pressure = Data2_Pressure1.append([Data2_Pressure2, Data2_Pressure3, Data2_Pressure4, Data2_Pressure5], ignore_index=True)

# %%
df2_intensity = Data2_Intensity1.append([Data2_Intensity2, Data2_Intensity3, Data2_Intensity4, Data2_Intensity5], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_17356\2828402398.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2_intensity = Data2_Intensity1.append([Data2_Intensity2, Data2_Intensity3, Data2_Intensity4, Data2_Intensity5], ignore_index=True)

# %%
df2_intensity
# Out:
#     Brightness  Reference_Time
# 0   163.058824        180034.0
# 1   161.610458        180035.0
# 2   157.180392        180036.0
# 3   156.704575        180037.0
# 4   156.690196        180038.0
# 5   156.726797        180039.0
# 6   156.669281        180040.0
# 7   156.696078        180041.0
# 8   156.840523        180042.0
# 9   179.967320        180236.0
# 10  186.996078        180237.0
# 11  187.200654        180238.0
# 12  188.934641        180239.0
# 13  189.234641        180240.0
# 14  188.453595        180241.0
# 15  164.805882        180242.0
# 16  164.341830        180243.0
# 17  164.258824        180244.0
# 18  162.309804        180356.0
# 19  162.352941        180357.0
# 20  161.962745        180358.0
# 21  161.794118        180359.0
# 22  162.033987        180360.0
# 23  162.146405        180361.0
# 24  172.847712        180362.0
# 25  173.292157        180363.0
# 26  176.353595        180364.0
# 27  205.505229        180429.0
# 28  186.645752        180430.0
# ...

# %%
df2_Pressure
# Out:
#     Reference_Time  Pressure   FSR
# 0           180034  0.000021   336
# 1           180035  0.000021   352
# 2           180036  0.000021   320
# 3           180037  0.000021   320
# 4           180038  0.000021   320
# 5           180039  0.000021   336
# 6           180040  0.000021   320
# 7           180041  0.000021   352
# 8           180042  0.000021   304
# 9           180236  0.000037  1584
# 10          180237  0.000034  1456
# 11          180238  0.000035  1488
# 12          180239  0.000039  1680
# 13          180240  0.000039  1696
# 14          180241  0.000042  1808
# 15          180242  0.000040  1728
# 16          180243  0.000039  1664
# 17          180244  0.000040  1728
# 18          180356  0.000024   672
# 19          180357  0.000023   560
# 20          180358  0.000025   816
# 21          180359  0.000026   832
# 22          180360  0.000027   928
# 23          180361  0.000026   896
# 24          180362  0.000026   896
# 25          180363  0.000028  1024
# ...

# %%
Lighting_Condition3 = pd.merge(df2_intensity, df2_Pressure,on='Reference_Time',how='inner')

# %%
headerList3 = ['Brightness','Reference_Time','Pressure','FSR']
Lighting_Condition3.to_csv("Lighting_Condition3.csv",header=headerList3, index=False)

# %%
#Run from here

# %%
Lighting_Condition3 = pd.read_csv('Lighting_Condition3.csv')

# %%
Lighting_Condition3
# Out:
#     Brightness  Reference_Time  Pressure   FSR
# 0     123.6780          195130  0.000021   256
# 1     126.6780          195131  0.000021   272
# 2     129.6780          194617  0.000021   288
# 3     140.6780          194612  0.000021   304
# 4     146.7800          195138  0.000021   320
# 5     148.6780          194616  0.000021   336
# 6     175.6789          195632  0.000022   800
# 7     179.6780          195134  0.000022   990
# 8     184.6780          195628  0.000022  1100
# 9     187.6780          195630  0.000022  1200
# 10    190.6789          195629  0.000022  1245
# 11    192.7890          195135  0.000022  1497
# 12    194.7890          195341  0.000094  2624
# 13    197.6780          195346  0.000106  2704
# 14    200.6780          195343  0.000123  2784
# 15    210.7890          195345  0.000131  2816

# %%
x1 = Lighting_Condition3['Brightness']
y1 = Lighting_Condition3['FSR']

# %%
plt.plot(x1, y1,label='Lighting_Condition3')

plt.legend(loc='upper left')

plt.xlabel('Brightness')
plt.ylabel('FSR (Volts)')

plt.show()

# %%
# reading two csv files(Lighting Condition 1)
data2_intensity1 = pd.read_csv('violet_0_side_intensity.csv')
data2_pressure1 = pd.read_csv('violet_0_lighting3_FSR.csv')

data2_intensity2 = pd.read_csv('violet_10_side_intensity.csv')
data2_pressure2 = pd.read_csv('violet_10_lighting3_FSR.csv')

data2_intensity3 = pd.read_csv('violet_25_side_intensity.csv')
data2_pressure3 = pd.read_csv('violet_25_lighting3_FSR.csv')

data2_intensity4 = pd.read_csv('violet_35_side_intensity.csv')
data2_pressure4 = pd.read_csv('violet_35_lighting3_FSR.csv')

data2_intensity5 = pd.read_csv('violet_50_side_intensity.csv')
data2_pressure5 = pd.read_csv('violet_50_lighting3_FSR.csv')

# %%
data2_intensity1.to_csv("Intensity_violet_Test1.csv", header=headerList_1, index=False)
data2_pressure1.to_csv("Pressure_violet_Test1.csv",header=headerList2, index=False)

data2_intensity2.to_csv("Intensity_violet_Test2.csv", header=headerList_1, index=False)
data2_pressure2.to_csv("Pressure_violet_Test2.csv",header=headerList2, index=False)

data2_intensity3.to_csv("Intensity_violet_Test3.csv", header=headerList_1, index=False)
data2_pressure3.to_csv("Pressure_violet_Test3.csv",header=headerList2, index=False)

data2_intensity4.to_csv("Intensity_violet_Test4.csv", header=headerList_1, index=False)
data2_pressure4.to_csv("Pressure_violet_Test4.csv",header=headerList2, index=False)

data2_intensity5.to_csv("Intensity_violet_Test5.csv", header=headerList_1, index=False)
data2_pressure5.to_csv("Pressure_violet_Test5.csv",header=headerList2, index=False)

# %%
# reading two csv files(Lighting Condition 3)
Data_violet_Intensity1 = pd.read_csv('Intensity_violet_Test1.csv')
Data_violet_Pressure1 = pd.read_csv('Pressure_violet_Test1.csv')

# reading two csv files(Lighting Condition 3)
Data_violet_Intensity2 = pd.read_csv('Intensity_violet_Test2.csv')
Data_violet_Pressure2 = pd.read_csv('Pressure_violet_Test2.csv')

Data_violet_Intensity3 = pd.read_csv('Intensity_violet_Test3.csv')
Data_violet_Pressure3 = pd.read_csv('Pressure_violet_Test3.csv')

Data_violet_Intensity4 = pd.read_csv('Intensity_violet_Test4.csv')
Data_violet_Pressure4 = pd.read_csv('Pressure_violet_Test4.csv')

Data_violet_Intensity5 = pd.read_csv('Intensity_violet_Test5.csv')
Data_violet_Pressure5 = pd.read_csv('Pressure_violet_Test5.csv')

# %%
df_violet_Pressure = Data_violet_Pressure1.append([Data_violet_Pressure2, Data_violet_Pressure3, Data_violet_Pressure4, Data_violet_Pressure5], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_17356\3208322818.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_violet_Pressure = Data_violet_Pressure1.append([Data_violet_Pressure2, Data_violet_Pressure3, Data_violet_Pressure4, Data_violet_Pressure5], ignore_index=True)

# %%
df_violet_Intensity = Data_violet_Intensity1.append([Data_violet_Intensity2, Data_violet_Intensity3, Data_violet_Intensity4, Data_violet_Intensity5], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_17356\1941857933.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_violet_Intensity = Data_violet_Intensity1.append([Data_violet_Intensity2, Data_violet_Intensity3, Data_violet_Intensity4, Data_violet_Intensity5], ignore_index=True)

# %%
Lighting_violet_Condition3 = pd.merge(df_violet_Intensity, df_violet_Pressure,on='Reference_Time',how='inner')

# %%
headerList3 = ['Brightness','Reference_Time','Pressure','FSR']
Lighting_violet_Condition3.to_csv("Lighting_violet_Condition3.csv",header=headerList3, index=False)

# %%
#for violet

# %%
Lighting_violet_Condition3 = pd.read_csv('Lighting_violet_Condition3.csv')

# %%
x2 = Lighting_violet_Condition3['Brightness']
y2 = Lighting_violet_Condition3['FSR']

# %%
plt.plot(x2, y2,label='Lighting_Condition3')

plt.legend(loc='upper left')

plt.xlabel('Brightness')
plt.ylabel('FSR (Volts)')

plt.show()

# %%
# reading two csv files(Lighting Condition 1)
data2_intensity1 = pd.read_csv('pink_0_side_intensity.csv')
data2_pressure1 = pd.read_csv('pink_0_lighting3_FSR.csv')

data2_intensity2 = pd.read_csv('pink_10_side_intensity.csv')
data2_pressure2 = pd.read_csv('pink_10_lighting3_FSR.csv')

data2_intensity3 = pd.read_csv('pink_25_side_intensity.csv')
data2_pressure3 = pd.read_csv('pink_25_lighting3_FSR.csv')

data2_intensity4 = pd.read_csv('pink_35_side_intensity.csv')
data2_pressure4 = pd.read_csv('pink_35_lighting3_FSR.csv')

# %%
data2_intensity1.to_csv("Intensity_pink_Test1.csv", header=headerList_1, index=False)
data2_pressure1.to_csv("Pressure_pink_Test1.csv",header=headerList2, index=False)

data2_intensity2.to_csv("Intensity_pink_Test2.csv", header=headerList_1, index=False)
data2_pressure2.to_csv("Pressure_pink_Test2.csv",header=headerList2, index=False)

data2_intensity3.to_csv("Intensity_pink_Test3.csv", header=headerList_1, index=False)
data2_pressure3.to_csv("Pressure_pink_Test3.csv",header=headerList2, index=False)

data2_intensity4.to_csv("Intensity_pink_Test4.csv", header=headerList_1, index=False)
data2_pressure4.to_csv("Pressure_pink_Test4.csv",header=headerList2, index=False)

# %%
# reading two csv files(Lighting Condition 3)
Data_pink_Intensity1 = pd.read_csv('Intensity_pink_Test1.csv')
Data_pink_Pressure1 = pd.read_csv('Pressure_pink_Test1.csv')

# reading two csv files(Lighting Condition 3)
Data_pink_Intensity2 = pd.read_csv('Intensity_pink_Test2.csv')
Data_pink_Pressure2 = pd.read_csv('Pressure_pink_Test2.csv')

Data_pink_Intensity3 = pd.read_csv('Intensity_pink_Test3.csv')
Data_pink_Pressure3 = pd.read_csv('Pressure_pink_Test3.csv')

Data_pink_Intensity4 = pd.read_csv('Intensity_pink_Test4.csv')
Data_pink_Pressure4 = pd.read_csv('Pressure_pink_Test4.csv')

# %%
df_pink_Pressure = Data_pink_Pressure1.append([Data_pink_Pressure2, Data_pink_Pressure3, Data_pink_Pressure4], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_17356\3513612430.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pink_Pressure = Data_pink_Pressure1.append([Data_pink_Pressure2, Data_pink_Pressure3, Data_pink_Pressure4], ignore_index=True)

# %%
df_pink_Intensity = Data_pink_Intensity1.append([Data_pink_Intensity2, Data_pink_Intensity3, Data_pink_Intensity4], ignore_index=True)
# Out:
# C:\Users\duggi\AppData\Local\Temp\ipykernel_17356\3503718462.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pink_Intensity = Data_pink_Intensity1.append([Data_pink_Intensity2, Data_pink_Intensity3, Data_pink_Intensity4], ignore_index=True)

# %%
df_pink_Intensity['Reference_Time'] = df_pink_Pressure['Reference_Time']

# %%
Lighting_pink_Condition3 = pd.merge(df_pink_Intensity, df_pink_Pressure,on='Reference_Time',how='inner')

# %%
Lighting_pink_Condition3
# Out:
#     Brightness  Reference_Time  Pressure   FSR
# 0   125.541830          200502  0.000021   352
# 1   125.541830          200503  0.000021   320
# 2   125.580392          200504  0.000021   352
# 3   125.580392          200505  0.000021   352
# 4   126.295425          200506  0.000021   336
# 5   126.295425          200507  0.000021   304
# 6   125.732026          200508  0.000021   352
# 7   125.732026          200509  0.000021   336
# 8   125.441176          200510  0.000021   352
# 9   209.303268          200522  0.000021   352
# 10  205.750327          200523  0.000021   336
# 11  206.134641          200524  0.000021   304
# 12  203.480392          200525  0.000021   304
# 13  198.305882          200526  0.000021   272
# 14  194.273856          200527  0.000021   336
# 15  123.073856          200528  0.000021   304
# 16  122.988889          200529  0.000021   320
# 17  123.026144          200530  0.000021   320
# 18  189.456863          200532  0.000038  1616
# ...

# %%
headerList3 = ['Brightness','Reference_Time','Pressure','FSR']
Lighting_pink_Condition3.to_csv("Lighting_pink_Condition3.csv",header=headerList3, index=False)

# %%
df_pink_Intensity
# Out:
#     Brightness  Reference_Time
# 0   124.718954         52506.0
# 1   124.390850         52507.0
# 2   123.504575         52508.0
# 3   119.962092         52509.0
# 4   119.739869         52510.0
# 5   119.300000         52511.0
# 6   119.177778         52512.0
# 7   119.476471         52513.0
# 8   119.667320         52514.0
# 9   110.720261         52514.0
# 10  110.606536         52515.0
# 11  110.816340         52516.0
# 12  117.720915         52517.0
# 13  129.244444         52518.0
# 14  128.994118         52519.0
# 15  129.344444         52520.0
# 16  129.443137         52521.0
# 17  125.281046         52522.0
# 18  142.402614         52607.0
# 19  143.211111         52608.0
# 20  142.435294         52609.0
# 21  141.653595         52610.0
# 22  141.967320         52611.0
# 23  137.739216         52612.0
# 24  115.832680         52613.0
# 25  115.883660         52614.0
# 26  115.496732         52615.0
# 27  157.842484         52612.0
# 28  156.629412         52613.0
# ...

# %%
#for pink

# %%
Lighting_pink_Condition3 = pd.read_csv('Lighting_pink_Condition3.csv')

# %%
x3 = Lighting_pink_Condition3['Brightness']
y3 = Lighting_pink_Condition3['FSR']

# %%
plt.plot(x3, y3,label='Lighting_Condition1')

plt.legend(loc='upper left')

plt.xlabel('Brightness')
plt.ylabel('FSR (Volts)')

plt.show()

# %%
x1 = Lighting_Condition3['Brightness']
y1 = Lighting_Condition3['FSR']

x3 = Lighting_pink_Condition3['Brightness']
y3 = Lighting_pink_Condition3['FSR']

x2 = Lighting_violet_Condition3['Brightness']
y2 = Lighting_violet_Condition3['FSR']

plt.plot(x1, y1,label='Background_Blue')
plt.plot(x2, y2,label='Background_Violet')
plt.plot(x3, y3,label='background_Pink')
plt.legend(loc='upper left')

plt.xlabel('Brightness')
plt.ylabel('FSR (Volts)')

plt.show()
